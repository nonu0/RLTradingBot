# %%
import seaborn as sns
import pandas as pd
data = pd.read_csv(r'C:\Users\Administrator\work\RLTrading\Bot\data\processed\processed.csv',index_col=['time'])
df = pd.DataFrame(data)
df.drop(['Unnamed: 0'],axis=1,inplace=True)
# Out:
#                         open     high      low    close  tick_volume  spread  \
# time
# 2018-07-19 00:00:00  112.794  113.166  112.055  112.359        53432       0
# 2018-07-20 00:00:00  112.358  112.614  111.381  111.413        55731       0
# 2018-07-22 00:00:00  111.358  111.485  111.031  111.053         4519       0
# 2018-07-23 00:00:00  111.053  111.536  110.741  111.458        52519       0
# 2018-07-24 00:00:00  111.460  111.460  110.956  111.276        48195       0
# ...                      ...      ...      ...      ...          ...     ...
# 2025-04-08 02:00:00  147.538  147.548  147.248  147.318         6362       9
# 2025-04-08 03:00:00  147.318  147.629  147.261  147.591         5554       9
# 2025-04-08 04:00:00  147.591  147.763  147.449  147.758         5593       9
# 2025-04-08 05:00:00  147.758  147.798  147.576  147.597         5996       9
# 2025-04-08 06:00:00  147.595  147.603  147.251  147.344         7625       9
#
#                      log_returns
# ...

# %% [markdown]
# Closing Prices vs Time

# %%
import matplotlib.pyplot as plt
sns.histplot(df,x='time',y='close')
plt.figure(figsize=(700,600))
plt.show()

# %% [markdown]
# Tick Volume vs Time

# %%
import matplotlib.pyplot as plt
sns.boxplot(df,x='time',y='tick_volume')
plt.figure(figsize=(700,600))
plt.show()

# %%
sns.barplot(df,x='time',y='tick_volume')
# Out:
# <Axes: xlabel='time', ylabel='tick_volume'>

# %% [markdown]
# Log Returns vs Time

# %%
sns.scatterplot(df,x='time',y='log_returns')
sns.rugplot(df,x='time',y='log_returns')
# Out:
# <Axes: xlabel='time', ylabel='log_returns'>
